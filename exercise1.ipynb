# %%
ice_cream_rating=4
sleeping_rating=3

# %%
first_name=input('first_name')
# Out:
# first_name Dmitry

# %%
first_name=input('first_name')
last_name=input('last_name')
my_name=first_name+' '+last_name
# Out:
# first_name Dmirty
# last_name Litvin

# %%
happiness_rating=(ice_cream_rating+sleeping_rating)/2
print(happiness_rating)
# Out:
# 3.5

# %%
type(ice_cream_rating),type(sleeping_rating), type(happiness_rating)
# Out:
# (int, int, float)

# %% [markdown]
# Yes, No

# %%
#My name is Dave and I give eating ice cream a score of 9 out of 10!
print('My name is '+first_name+' and I give eating ice cream a score of '+str(ice_cream_rating)+' out of 10!')
# Out:
# My name is Dmirty and I give eating ice cream a score of 4 out of 10!

# %%
#I am Dave Whipp and my sleeping enjoyment rating is 8 / 10!
print('I am '+my_name+' and my sleeping enjoyment rating is '+str(sleeping_rating)+' / 10!')
# Out:
# I am Dmirty Litvin and my sleeping enjoyment rating is 3 / 10!

# %%
#Based on the factors above, my happiness rating is 8.5 out of 10, or 85.0 %!
print('Based on the factors above, my happiness rating is '+str(happiness_rating)+' out of 10, or '+str(10*happiness_rating)+' %!')
# Out:
# Based on the factors above, my happiness rating is 3.5 out of 10, or 35.0 %!
